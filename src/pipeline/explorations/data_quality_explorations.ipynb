# %% [markdown]
# ### ILEC Data Exploration
#
# Use this notebook to explore the data generated by the pipeline in your preferred programming language.
#
# **Note**: This notebook is not executed as part of the pipeline.

# %%
from collections import defaultdict
from pyspark.sql import functions as F
from typing import Dict, List

import sys
sys.path.append('../')

# %load_ext autoreload
# %autoreload 2

from transformations import util as util

# %%
tbl_ilec = (
    spark.read.table("mlops_dev.default.ilec_data")
)

# %%
F.upp
